# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
from keras.models import model_from_yaml
import matplotlib.pyplot as plt

# %%
# fixar random seed para se puder reproduzir os resultados
seed = 9
np.random.seed(seed)

# %%
# Etapa 1 - preparar o dataset
'''
fazer o download do prima indian dataset sobre diabetes em população indigena (label
0,1 tem diabetes):
dataset: http://archive.ics.uci.edu/ml/datasets/Pima+Indians+Diabetes
download: http://archive.ics.uci.edu/ml/machine-learning-databases/pima-indiansdiabetes/pima-indians-diabetes.data
fazer o rename para pima-indians-diabetes.csv
'''
def read_cvs_dataset(ficheiro, col_label):
    # ler ficheiro csv para matriz numpy, e separar o label que está em col_label (deve ser a ultima coluna)
    dataset = np.loadtxt(ficheiro, delimiter=",")
    print('Formato do dataset: ',dataset.shape)
    input_attributes = dataset[:,0:col_label]
    output_attributes = dataset[:,col_label]
    print('Formato das variáveis de entrada (input variables): ', input_attributes.shape)
    print('Formato da classe de saída (output variables): ', output_attributes.shape)
    #print(X[0])
    #print(Y[0])
    return (input_attributes,output_attributes)

# Etapa 2 - Definir a topologia da rede (arquitectura do modelo)
'''
cria-se um modelo sequencial e vai-se acrescentando camadas (layers)
vamos criar 3 camadas no nosso modelo
Dense class significa que teremos um modelo fully connected
 o primeiro parametro estabelece o número de neuronios na camada (12 na primeira)
 input_dim=8 indica o número de entradas do nosso dataset (8 atributos neste caso)
 kernel_initializer indica o metodo de inicialização dos pesos das ligações
 'uniforme' sigifica small random number generator com default entre 0 e 0.05
 outra hipotese seria 'normal' com small number generator from Gaussion
distribution
 "activation" indica a activation fuction
 'relu' rectifier linear unit activation function com range entre 0 e infinito
 'sigmoid' foi utilizada para garantir um resultado entre 0 e 1
'''
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, activation="relu", kernel_initializer="uniform"))
    model.add(Dense(8, activation="relu", kernel_initializer="uniform"))
    model.add(Dense(1, activation="sigmoid", kernel_initializer="uniform"))
    return model

#util para visualizar a topologia da rede num ficheiro em pdf ou png
def print_model(model,fich):
    from keras.utils import plot_model
    plot_model(model, to_file=fich, show_shapes=True, show_layer_names=True)
    
# Etapa 3 - Compilar o modelo (especificar o modelo de aprendizagem a ser utilizado pela rede)
'''
loss - funcão a ser utilizada no calculo da diferença entre o pretendido e o obtido
vamos utilizar logaritmic loss para classificação binária: 'binary_crossentropy'
o algoritmo de gradient descent será o “adam” pois é eficiente
a métrica a ser utilizada no report durante o treino será 'accuracy' pois trata-se de
um problema de classificacao
'''
def compile_model(model):
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model 

# Etapa 4 - treinar a rede (Fit the model) neste caso foi feito com os dados todos
'''
'batch_size'número da casos processados de cada vez
model.fit(X, Y, nb_epoch=150, batch_size=10, verbose=2)
verbose: 0 para print do log de treino stdout, 1 para barra de progresso, 2 para uma
linha por epoch.
validation_split: float (0. < x < 1). Fração de dados a serem utilizados como dados de
validação.
'''
def fit_model(model,input_attributes,output_attributes):
    history = model.fit(input_attributes, output_attributes, validation_split=0.33, epochs=150, batch_size=10, verbose=2)
    return history

#utils para visulaização do historial de aprendizagem
def print_history_accuracy(history):
    print(history.history.keys())
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

def print_history_loss(history):
    print(history.history.keys())
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
# Etapa 5 - Calcular o desempenho do modelo treinado (neste caso utilizando os dados usados no treino) 
def model_evaluate(model,input_attributes,output_attributes):
    print("###########inicio do evaluate###############################\n")
    scores = model.evaluate(input_attributes, output_attributes)
    print("\n metrica: %s: %.2f%%\n"% (model.metrics_names[1], scores[1]*100))

# Etapa 6 - Utilizar o modelo treinado e escrever as previsões para novos casos
def model_print_predictions(model,input_attributes,output_attributes):
    previsoes= model.predict(input_attributes) 
    # arredondar para 0 ou 1 pois pretende-se um output binário
    LP=[]
    for prev in previsoes:
        LP.append(round(prev[0]))
    #LP = [round(prev[0]) for prev in previsoes]
    for i in range(len(output_attributes)):
        print(" Class:",output_attributes[i]," previsão:",LP[i])
        if i>10: break
            
# Ciclo completo executando as Etapas 1,2,3,4,5 e 6           
def ciclo_completo():
    (input_attributes, output_attributes) = read_cvs_dataset("pima-indians-diabetes.csv", 8)
    model = create_model()
    print_model(model,"model_MLP.png")
    compile_model(model)
    history = fit_model(model,input_attributes,output_attributes)
    print_history_accuracy(history)
    print_history_loss(history)
    model_evaluate(model,input_attributes,output_attributes)
    model_print_predictions(model,input_attributes,output_attributes)

# Utils para gravar modelos e pesos utilizá-los posteriormente
'''
Gravar um modelo num ficheiro utilizando o formato json. O nome do ficheiro deve ter a
extensão .json
'''
def save_model_json(model,fich):
    model_json = model.to_json()
    with open(fich, "w") as json_file:
        json_file.write(model_json)

'''
Gravar um modelo num ficheiro utilizando o formato yaml. O nome do ficheiro deve ter a
extensão .yaml
'''
def save_model_yaml(model,fich):
    model_yaml= model.to_yaml()
    with open(fich, "w") as yaml_file:
        yaml_file.write(model_yaml)
        
'''
Gravar os pesos de um modelo treinado num ficheiro utilizando o formato HDF5. O nome do
ficheiro deve ter a extensão .h5
'''        
def save_weights_hdf5(model,fich):
    model.save_weights(fich)
    print("Saved model to disk")

'''
Ler um modelo de um ficheiro no formato json e criar o respetivo modelo em memória.
'''
def load_model_json(fich):
    json_file= open(fich, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    return loaded_model

'''
Ler um modelo de um ficheiro no formato yaml e criar o respetivo modelo em memória.
'''
def load_model_yaml(fich):
    yaml_file = open(fich, 'r')
    loaded_model_yaml = yaml_file.read()
    yaml_file.close()
    return model_from_yaml(loaded_model_yaml)

'''
Ler os pesos um modelo treinado de um ficheiro no formato hdf5 para o respectivo
modelo.
''' 
def load_weights_hdf5(model,fich):
    model.load_weights(fich)
    print("Loaded model from disk")
    
# exemplos de utilização destes utilitários
def ciclo_ler_dataset_treinar_gravar():
    (input_attributes,output_attributes) = read_cvs_dataset("pima-indians-diabetes.csv",8)
    model = create_model()
    print_model(model,"model2.png")
    compile_model(model)
    history = fit_model(model,input_attributes,output_attributes)
    print_history_accuracy(history)
    print_history_loss(history)
    model_evaluate(model,input_attributes,output_attributes)
    save_model_json(model,"model.json")
    save_weights_hdf5(model,"model.h5")
    return(input_attributes,output_attributes)

def ciclo_ler_modelo_evaluate_usar(input_attributes,output_attributes):
    model = load_model_json("model.json")
    load_weights_hdf5(model,"model.h5")
    compile_model(model)
    model_evaluate(model,input_attributes,output_attributes)
    model_print_predictions(model,input_attributes,output_attributes)

# %%
if __name__ == '__main__':
    #opção1 -ciclocompleto
    #ciclo_completo()
    #opção 2 -ler, treinaro dataset e gravar. Depois ler o modelo e pesos e usar
    (input_attributes, output_attributes) = ciclo_ler_dataset_treinar_gravar()
    ciclo_ler_modelo_evaluate_usar(input_attributes,output_attributes)
# Out:
# Formato do dataset:  (768, 9)
# Formato das variáveis de entrada (input variables):  (768, 8)
# Formato da classe de saída (output variables):  (768,)
# Train on 514 samples, validate on 254 samples
# Epoch 1/150
#  - 1s - loss: 0.6865 - accuracy: 0.6342 - val_loss: 0.6693 - val_accuracy: 0.6732
# Epoch 2/150
#  - 0s - loss: 0.6720 - accuracy: 0.6401 - val_loss: 0.6581 - val_accuracy: 0.6732
# Epoch 3/150
#  - 0s - loss: 0.6659 - accuracy: 0.6381 - val_loss: 0.6542 - val_accuracy: 0.6811
# Epoch 4/150
#  - 0s - loss: 0.6622 - accuracy: 0.6323 - val_loss: 0.6528 - val_accuracy: 0.6772
# Epoch 5/150
#  - 0s - loss: 0.6554 - accuracy: 0.6420 - val_loss: 0.6449 - val_accuracy: 0.6693
# Epoch 6/150
#  - 0s - loss: 0.6482 - accuracy: 0.6479 - val_loss: 0.6403 - val_accuracy: 0.6890
# Epoch 7/150
#  - 0s - loss: 0.6426 - accuracy: 0.6595 - val_loss: 0.6380 - val_accuracy: 0.6535
# Epoch 8/150
#  - 0s - loss: 0.6389 - accuracy: 0.6673 - val_loss: 0.6326 - val_accuracy: 0.6693
# Epoch 9/150
#  - 0s - loss: 0.6336 - accuracy: 0.6576 - val_loss: 0.6183 - val_accuracy: 0.6772
# Epoch 10/150
#  - 0s - loss: 0.6282 - accuracy: 0.6576 - val_loss: 0.6096 - val_accuracy: 0.6811
# Epoch 11/150
#  - 0s - loss: 0.6266 - accuracy: 0.6498 - val_loss: 0.6209 - val_accuracy: 0.6535
# Epoch 12/150
#  - 0s - loss: 0.6217 - accuracy: 0.6595 - val_loss: 0.6051 - val_accuracy: 0.6890
# Epoch 13/150
#  - 0s - loss: 0.6173 - accuracy: 0.6712 - val_loss: 0.5998 - val_accuracy: 0.6890
# Epoch 14/150
#  - 0s - loss: 0.6133 - accuracy: 0.6848 - val_loss: 0.5908 - val_accuracy: 0.7047
# Epoch 15/150
#  - 0s - loss: 0.6116 - accuracy: 0.6868 - val_loss: 0.5917 - val_accuracy: 0.6850
# Epoch 16/150
#  - 1s - loss: 0.6095 - accuracy: 0.6751 - val_loss: 0.5866 - val_accuracy: 0.7047
# Epoch 17/150
#  - 1s - loss: 0.6006 - accuracy: 0.6829 - val_loss: 0.5761 - val_accuracy: 0.7087
# Epoch 18/150
#  - 1s - loss: 0.6027 - accuracy: 0.6984 - val_loss: 0.5758 - val_accuracy: 0.7008
# Epoch 19/150
#  - 2s - loss: 0.5969 - accuracy: 0.6946 - val_loss: 0.5699 - val_accuracy: 0.7205
# Epoch 20/150
#  - 1s - loss: 0.6004 - accuracy: 0.6907 - val_loss: 0.5737 - val_accuracy: 0.7283
# Epoch 21/150
#  - 1s - loss: 0.6031 - accuracy: 0.7023 - val_loss: 0.6029 - val_accuracy: 0.6811
# Epoch 22/150
#  - 1s - loss: 0.6047 - accuracy: 0.7004 - val_loss: 0.5742 - val_accuracy: 0.7362
# Epoch 23/150
#  - 2s - loss: 0.5950 - accuracy: 0.7082 - val_loss: 0.5703 - val_accuracy: 0.7008
# Epoch 24/150
#  - 1s - loss: 0.5965 - accuracy: 0.7043 - val_loss: 0.5839 - val_accuracy: 0.7008
# Epoch 25/150
#  - 2s - loss: 0.6063 - accuracy: 0.7160 - val_loss: 0.5711 - val_accuracy: 0.7244
# Epoch 26/150
#  - 2s - loss: 0.5874 - accuracy: 0.7140 - val_loss: 0.5635 - val_accuracy: 0.7283
# Epoch 27/150
#  - 1s - loss: 0.5845 - accuracy: 0.7218 - val_loss: 0.5619 - val_accuracy: 0.7126
# Epoch 28/150
#  - 2s - loss: 0.5781 - accuracy: 0.7218 - val_loss: 0.5626 - val_accuracy: 0.7126
# Epoch 29/150
#  - 2s - loss: 0.5868 - accuracy: 0.7179 - val_loss: 0.5651 - val_accuracy: 0.7244
# Epoch 30/150
#  - 2s - loss: 0.5776 - accuracy: 0.7257 - val_loss: 0.5585 - val_accuracy: 0.7283
# Epoch 31/150
#  - 1s - loss: 0.5781 - accuracy: 0.7198 - val_loss: 0.5565 - val_accuracy: 0.7087
# Epoch 32/150
#  - 1s - loss: 0.5678 - accuracy: 0.7179 - val_loss: 0.5572 - val_accuracy: 0.7087
# Epoch 33/150
#  - 1s - loss: 0.5704 - accuracy: 0.7218 - val_loss: 0.5483 - val_accuracy: 0.7362
# Epoch 34/150
#  - 2s - loss: 0.5700 - accuracy: 0.7140 - val_loss: 0.5465 - val_accuracy: 0.7244
# Epoch 35/150
#  - 1s - loss: 0.5664 - accuracy: 0.7237 - val_loss: 0.5547 - val_accuracy: 0.7323
# Epoch 36/150
#  - 1s - loss: 0.5628 - accuracy: 0.7257 - val_loss: 0.5504 - val_accuracy: 0.7323
# Epoch 37/150
#  - 2s - loss: 0.5609 - accuracy: 0.7315 - val_loss: 0.5535 - val_accuracy: 0.7165
# Epoch 38/150
#  - 2s - loss: 0.5601 - accuracy: 0.7121 - val_loss: 0.5610 - val_accuracy: 0.7283
# Epoch 39/150
#  - 2s - loss: 0.5578 - accuracy: 0.7315 - val_loss: 0.5551 - val_accuracy: 0.7402
# Epoch 40/150
#  - 2s - loss: 0.5574 - accuracy: 0.7276 - val_loss: 0.5549 - val_accuracy: 0.7323
# Epoch 41/150
#  - 2s - loss: 0.5577 - accuracy: 0.7276 - val_loss: 0.5462 - val_accuracy: 0.7402
# Epoch 42/150
#  - 1s - loss: 0.5566 - accuracy: 0.7257 - val_loss: 0.5626 - val_accuracy: 0.7205
# Epoch 43/150
#  - 1s - loss: 0.5606 - accuracy: 0.7237 - val_loss: 0.5491 - val_accuracy: 0.7283
# Epoch 44/150
#  - 1s - loss: 0.5543 - accuracy: 0.7296 - val_loss: 0.5484 - val_accuracy: 0.7205
# Epoch 45/150
#  - 1s - loss: 0.5566 - accuracy: 0.7257 - val_loss: 0.5447 - val_accuracy: 0.7441
# Epoch 46/150
#  - 2s - loss: 0.5509 - accuracy: 0.7257 - val_loss: 0.5480 - val_accuracy: 0.7244
# Epoch 47/150
#  - 2s - loss: 0.5555 - accuracy: 0.7296 - val_loss: 0.5385 - val_accuracy: 0.7402
# Epoch 48/150
#  - 1s - loss: 0.5571 - accuracy: 0.7257 - val_loss: 0.5394 - val_accuracy: 0.7520
# Epoch 49/150
#  - 1s - loss: 0.5472 - accuracy: 0.7393 - val_loss: 0.5520 - val_accuracy: 0.7244
# Epoch 50/150
#  - 1s - loss: 0.5502 - accuracy: 0.7237 - val_loss: 0.5376 - val_accuracy: 0.7559
# Epoch 51/150
#  - 1s - loss: 0.5508 - accuracy: 0.7237 - val_loss: 0.5423 - val_accuracy: 0.7441
# Epoch 52/150
#  - 1s - loss: 0.5431 - accuracy: 0.7276 - val_loss: 0.5429 - val_accuracy: 0.7244
# Epoch 53/150
#  - 1s - loss: 0.5428 - accuracy: 0.7296 - val_loss: 0.5493 - val_accuracy: 0.7205
# Epoch 54/150
#  - 1s - loss: 0.5430 - accuracy: 0.7412 - val_loss: 0.5384 - val_accuracy: 0.7402
# Epoch 55/150
#  - 1s - loss: 0.5444 - accuracy: 0.7335 - val_loss: 0.5415 - val_accuracy: 0.7283
# Epoch 56/150
#  - 1s - loss: 0.5453 - accuracy: 0.7257 - val_loss: 0.5485 - val_accuracy: 0.7087
# Epoch 57/150
#  - 1s - loss: 0.5459 - accuracy: 0.7276 - val_loss: 0.5342 - val_accuracy: 0.7520
# Epoch 58/150
#  - 1s - loss: 0.5403 - accuracy: 0.7315 - val_loss: 0.5507 - val_accuracy: 0.7205
# Epoch 59/150
#  - 1s - loss: 0.5492 - accuracy: 0.7179 - val_loss: 0.5513 - val_accuracy: 0.7205
# Epoch 60/150
#  - 2s - loss: 0.5359 - accuracy: 0.7276 - val_loss: 0.5411 - val_accuracy: 0.7362
# Epoch 61/150
#  - 1s - loss: 0.5356 - accuracy: 0.7393 - val_loss: 0.5411 - val_accuracy: 0.7205
# Epoch 62/150
#  - 1s - loss: 0.5426 - accuracy: 0.7335 - val_loss: 0.5400 - val_accuracy: 0.7362
# Epoch 63/150
#  - 1s - loss: 0.5355 - accuracy: 0.7393 - val_loss: 0.5484 - val_accuracy: 0.7205
# Epoch 64/150
#  - 1s - loss: 0.5373 - accuracy: 0.7393 - val_loss: 0.5370 - val_accuracy: 0.7441
# Epoch 65/150
#  - 2s - loss: 0.5365 - accuracy: 0.7237 - val_loss: 0.5307 - val_accuracy: 0.7362
# Epoch 66/150
#  - 2s - loss: 0.5372 - accuracy: 0.7412 - val_loss: 0.5506 - val_accuracy: 0.7165
# Epoch 67/150
#  - 1s - loss: 0.5469 - accuracy: 0.7218 - val_loss: 0.5343 - val_accuracy: 0.7480
# Epoch 68/150
#  - 1s - loss: 0.5325 - accuracy: 0.7374 - val_loss: 0.5268 - val_accuracy: 0.7480
# Epoch 69/150
#  - 1s - loss: 0.5359 - accuracy: 0.7276 - val_loss: 0.5403 - val_accuracy: 0.7323
# Epoch 70/150
#  - 1s - loss: 0.5356 - accuracy: 0.7354 - val_loss: 0.5378 - val_accuracy: 0.7402
# Epoch 71/150
#  - 1s - loss: 0.5355 - accuracy: 0.7315 - val_loss: 0.5323 - val_accuracy: 0.7441
# Epoch 72/150
#  - 1s - loss: 0.5295 - accuracy: 0.7354 - val_loss: 0.5220 - val_accuracy: 0.7598
# Epoch 73/150
#  - 1s - loss: 0.5297 - accuracy: 0.7374 - val_loss: 0.5325 - val_accuracy: 0.7362
# Epoch 74/150
#  - 2s - loss: 0.5288 - accuracy: 0.7257 - val_loss: 0.5281 - val_accuracy: 0.7480
# Epoch 75/150
#  - 1s - loss: 0.5382 - accuracy: 0.7393 - val_loss: 0.5454 - val_accuracy: 0.7362
# Epoch 76/150
#  - 1s - loss: 0.5282 - accuracy: 0.7393 - val_loss: 0.5394 - val_accuracy: 0.7362
# Epoch 77/150
#  - 1s - loss: 0.5326 - accuracy: 0.7374 - val_loss: 0.5323 - val_accuracy: 0.7362
# Epoch 78/150
#  - 1s - loss: 0.5293 - accuracy: 0.7432 - val_loss: 0.5297 - val_accuracy: 0.7402
# Epoch 79/150
#  - 1s - loss: 0.5279 - accuracy: 0.7257 - val_loss: 0.5337 - val_accuracy: 0.7441
# Epoch 80/150
#  - 2s - loss: 0.5237 - accuracy: 0.7354 - val_loss: 0.5338 - val_accuracy: 0.7441
# Epoch 81/150
#  - 2s - loss: 0.5241 - accuracy: 0.7315 - val_loss: 0.5374 - val_accuracy: 0.7441
# Epoch 82/150
#  - 2s - loss: 0.5298 - accuracy: 0.7471 - val_loss: 0.5812 - val_accuracy: 0.6850
# Epoch 83/150
#  - 1s - loss: 0.5285 - accuracy: 0.7354 - val_loss: 0.5299 - val_accuracy: 0.7323
# Epoch 84/150
#  - 1s - loss: 0.5294 - accuracy: 0.7276 - val_loss: 0.5111 - val_accuracy: 0.7756
# Epoch 85/150
#  - 2s - loss: 0.5251 - accuracy: 0.7393 - val_loss: 0.5339 - val_accuracy: 0.7441
# Epoch 86/150
#  - 1s - loss: 0.5253 - accuracy: 0.7393 - val_loss: 0.5284 - val_accuracy: 0.7520
# Epoch 87/150
#  - 1s - loss: 0.5207 - accuracy: 0.7451 - val_loss: 0.5123 - val_accuracy: 0.7520
# Epoch 88/150
#  - 1s - loss: 0.5225 - accuracy: 0.7374 - val_loss: 0.5112 - val_accuracy: 0.7677
# Epoch 89/150
#  - 1s - loss: 0.5216 - accuracy: 0.7432 - val_loss: 0.5162 - val_accuracy: 0.7559
# Epoch 90/150
#  - 1s - loss: 0.5285 - accuracy: 0.7393 - val_loss: 0.5149 - val_accuracy: 0.7717
# Epoch 91/150
#  - 2s - loss: 0.5241 - accuracy: 0.7432 - val_loss: 0.5396 - val_accuracy: 0.7323
# Epoch 92/150
#  - 1s - loss: 0.5173 - accuracy: 0.7510 - val_loss: 0.5190 - val_accuracy: 0.7441
# Epoch 93/150
#  - 1s - loss: 0.5195 - accuracy: 0.7412 - val_loss: 0.5187 - val_accuracy: 0.7480
# Epoch 94/150
#  - 2s - loss: 0.5222 - accuracy: 0.7490 - val_loss: 0.5692 - val_accuracy: 0.7087
# Epoch 95/150
#  - 1s - loss: 0.5196 - accuracy: 0.7451 - val_loss: 0.5151 - val_accuracy: 0.7638
# Epoch 96/150
#  - 1s - loss: 0.5108 - accuracy: 0.7374 - val_loss: 0.5227 - val_accuracy: 0.7638
# Epoch 97/150
#  - 1s - loss: 0.5141 - accuracy: 0.7549 - val_loss: 0.5308 - val_accuracy: 0.7362
# Epoch 98/150
#  - 1s - loss: 0.5187 - accuracy: 0.7471 - val_loss: 0.5307 - val_accuracy: 0.7480
# Epoch 99/150
#  - 1s - loss: 0.5176 - accuracy: 0.7490 - val_loss: 0.5165 - val_accuracy: 0.7598
# Epoch 100/150
#  - 1s - loss: 0.5145 - accuracy: 0.7529 - val_loss: 0.5141 - val_accuracy: 0.7835
# Epoch 101/150
#  - 1s - loss: 0.5098 - accuracy: 0.7529 - val_loss: 0.5166 - val_accuracy: 0.7559
# Epoch 102/150
#  - 1s - loss: 0.5170 - accuracy: 0.7315 - val_loss: 0.5200 - val_accuracy: 0.7638
# Epoch 103/150
#  - 0s - loss: 0.5121 - accuracy: 0.7626 - val_loss: 0.5222 - val_accuracy: 0.7638
# Epoch 104/150
#  - 0s - loss: 0.5088 - accuracy: 0.7490 - val_loss: 0.5147 - val_accuracy: 0.7638
# Epoch 105/150
#  - 0s - loss: 0.5074 - accuracy: 0.7412 - val_loss: 0.5207 - val_accuracy: 0.7480
# Epoch 106/150
#  - 0s - loss: 0.5233 - accuracy: 0.7588 - val_loss: 0.5252 - val_accuracy: 0.7402
# Epoch 107/150
#  - 0s - loss: 0.5052 - accuracy: 0.7471 - val_loss: 0.5415 - val_accuracy: 0.7362
# Epoch 108/150
#  - 0s - loss: 0.5046 - accuracy: 0.7451 - val_loss: 0.5149 - val_accuracy: 0.7559
# Epoch 109/150
#  - 0s - loss: 0.5044 - accuracy: 0.7471 - val_loss: 0.5291 - val_accuracy: 0.7441
# Epoch 110/150
#  - 0s - loss: 0.5037 - accuracy: 0.7626 - val_loss: 0.5429 - val_accuracy: 0.7480
# Epoch 111/150
#  - 0s - loss: 0.5092 - accuracy: 0.7510 - val_loss: 0.5296 - val_accuracy: 0.7520
# Epoch 112/150
#  - 0s - loss: 0.5016 - accuracy: 0.7626 - val_loss: 0.5360 - val_accuracy: 0.7362
# Epoch 113/150
#  - 0s - loss: 0.5102 - accuracy: 0.7471 - val_loss: 0.5272 - val_accuracy: 0.7480
# Epoch 114/150
#  - 0s - loss: 0.5013 - accuracy: 0.7568 - val_loss: 0.5202 - val_accuracy: 0.7520
# Epoch 115/150
#  - 0s - loss: 0.5133 - accuracy: 0.7412 - val_loss: 0.5405 - val_accuracy: 0.7283
# Epoch 116/150
#  - 0s - loss: 0.4996 - accuracy: 0.7471 - val_loss: 0.5187 - val_accuracy: 0.7559
# Epoch 117/150
#  - 0s - loss: 0.4955 - accuracy: 0.7510 - val_loss: 0.5269 - val_accuracy: 0.7520
# Epoch 118/150
#  - 0s - loss: 0.4935 - accuracy: 0.7549 - val_loss: 0.5262 - val_accuracy: 0.7402
# Epoch 119/150
#  - 0s - loss: 0.5017 - accuracy: 0.7549 - val_loss: 0.5170 - val_accuracy: 0.7559
# Epoch 120/150
#  - 0s - loss: 0.4915 - accuracy: 0.7626 - val_loss: 0.5162 - val_accuracy: 0.7638
# Epoch 121/150
#  - 0s - loss: 0.4972 - accuracy: 0.7451 - val_loss: 0.5186 - val_accuracy: 0.7795
# Epoch 122/150
#  - 0s - loss: 0.4896 - accuracy: 0.7724 - val_loss: 0.5383 - val_accuracy: 0.7402
# Epoch 123/150
#  - 0s - loss: 0.4999 - accuracy: 0.7626 - val_loss: 0.5250 - val_accuracy: 0.7520
# Epoch 124/150
#  - 0s - loss: 0.4918 - accuracy: 0.7568 - val_loss: 0.5219 - val_accuracy: 0.7480
# Epoch 125/150
#  - 0s - loss: 0.4914 - accuracy: 0.7490 - val_loss: 0.5377 - val_accuracy: 0.7480
# Epoch 126/150
#  - 0s - loss: 0.4956 - accuracy: 0.7510 - val_loss: 0.5315 - val_accuracy: 0.7559
# Epoch 127/150
#  - 0s - loss: 0.4872 - accuracy: 0.7568 - val_loss: 0.5134 - val_accuracy: 0.7677
# Epoch 128/150
#  - 0s - loss: 0.4915 - accuracy: 0.7393 - val_loss: 0.5317 - val_accuracy: 0.7520
# Epoch 129/150
#  - 0s - loss: 0.4880 - accuracy: 0.7568 - val_loss: 0.5409 - val_accuracy: 0.7283
# Epoch 130/150
#  - 0s - loss: 0.4925 - accuracy: 0.7588 - val_loss: 0.5307 - val_accuracy: 0.7402
# Epoch 131/150
#  - 0s - loss: 0.4874 - accuracy: 0.7665 - val_loss: 0.5216 - val_accuracy: 0.7717
# Epoch 132/150
#  - 0s - loss: 0.4966 - accuracy: 0.7568 - val_loss: 0.5119 - val_accuracy: 0.7520
# Epoch 133/150
#  - 0s - loss: 0.4882 - accuracy: 0.7471 - val_loss: 0.5260 - val_accuracy: 0.7756
# Epoch 134/150
#  - 0s - loss: 0.4932 - accuracy: 0.7568 - val_loss: 0.5081 - val_accuracy: 0.7795
# Epoch 135/150
#  - 0s - loss: 0.4900 - accuracy: 0.7724 - val_loss: 0.5255 - val_accuracy: 0.7598
# Epoch 136/150
#  - 0s - loss: 0.4878 - accuracy: 0.7607 - val_loss: 0.5217 - val_accuracy: 0.7677
# Epoch 137/150
#  - 0s - loss: 0.4887 - accuracy: 0.7607 - val_loss: 0.5165 - val_accuracy: 0.7638
# Epoch 138/150
#  - 0s - loss: 0.4841 - accuracy: 0.7646 - val_loss: 0.5249 - val_accuracy: 0.7402
# Epoch 139/150
#  - 0s - loss: 0.4894 - accuracy: 0.7626 - val_loss: 0.5440 - val_accuracy: 0.7598
# Epoch 140/150
#  - 0s - loss: 0.4832 - accuracy: 0.7588 - val_loss: 0.5165 - val_accuracy: 0.7677
# Epoch 141/150
#  - 0s - loss: 0.4810 - accuracy: 0.7704 - val_loss: 0.5177 - val_accuracy: 0.7638
# Epoch 142/150
#  - 0s - loss: 0.4797 - accuracy: 0.7626 - val_loss: 0.5155 - val_accuracy: 0.7717
# Epoch 143/150
#  - 0s - loss: 0.4802 - accuracy: 0.7607 - val_loss: 0.5371 - val_accuracy: 0.7402
# Epoch 144/150
#  - 0s - loss: 0.4819 - accuracy: 0.7743 - val_loss: 0.5307 - val_accuracy: 0.7323
# Epoch 145/150
#  - 0s - loss: 0.4900 - accuracy: 0.7607 - val_loss: 0.5211 - val_accuracy: 0.7756
# Epoch 146/150
#  - 0s - loss: 0.4854 - accuracy: 0.7529 - val_loss: 0.5250 - val_accuracy: 0.7677
# Epoch 147/150
#  - 0s - loss: 0.4872 - accuracy: 0.7607 - val_loss: 0.5189 - val_accuracy: 0.7717
# Epoch 148/150
#  - 0s - loss: 0.4823 - accuracy: 0.7568 - val_loss: 0.5364 - val_accuracy: 0.7244
# Epoch 149/150
#  - 0s - loss: 0.4799 - accuracy: 0.7782 - val_loss: 0.5222 - val_accuracy: 0.7795
# Epoch 150/150
#  - 0s - loss: 0.4773 - accuracy: 0.7626 - val_loss: 0.5082 - val_accuracy: 0.7717
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])
# ###########inicio do evaluate###############################
#
# 768/768 [==============================] - 0s 315us/step
#
#  metrica: accuracy: 77.08%
#
# Saved model to disk
# Loaded model from disk
# ###########inicio do evaluate###############################
#
# 768/768 [==============================] - 1s 1ms/step
#
#  metrica: accuracy: 77.08%
#
#  Class: 1.0  previsão: 1.0
#  Class: 0.0  previsão: 0.0
#  Class: 1.0  previsão: 1.0
#  Class: 0.0  previsão: 0.0
#  Class: 1.0  previsão: 1.0
#  Class: 0.0  previsão: 0.0
#  Class: 1.0  previsão: 0.0
#  Class: 0.0  previsão: 1.0
#  Class: 1.0  previsão: 1.0
#  Class: 1.0  previsão: 1.0
#  Class: 0.0  previsão: 0.0
#  Class: 1.0  previsão: 1.0
