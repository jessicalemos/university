# %%
import os
from sklearn import preprocessing
from matplotlib import pyplot as plt
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("train_data.csv",sep=",")
test= pd.read_csv("test_data.csv",sep=",")
#for col in test.columns: 
#    print(col) 
data['Work load Average/day '] = [x.replace(',', '.') for x in data['Work load Average/day ']]
data['Work load Average/day '] = data['Work load Average/day '].astype(float)

# %%
pd.plotting.scatter_matrix(data,s=150, figsize=(40, 40),marker='D')
plt.show()

# %%
data = data.drop('ID', 1)
data.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          500.000000        500.000000        500.00000  500.000000
# mean            19.288000          6.614000          3.88000    2.450000
# std              8.543245          3.343555          1.43587    1.165425
# min              0.000000          1.000000          2.00000    1.000000
# 25%             13.000000          3.750000          3.00000    1.000000
# 50%             23.000000          7.000000          4.00000    2.000000
# 75%             26.000000          9.000000          5.00000    4.000000
# max             28.000000         12.000000          6.00000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              500.000000                       500.000000    500.000000
# mean               223.640000                        29.978000     12.650000
# std                 67.323155                        15.068498      4.036345
# ...

# %%
data = data.drop('ID', 1)

pd.options.display.max_columns = 2000
data = pd.DataFrame(data, columns=data.columns)
nRows = data.shape[0]
nBins = int(round(sqrt(nRows)))

for key in data.keys():
    data.hist(column=key, bins=nBins)

# %% [markdown]
# ## Outliers Analysis

# %%
data = data.drop('Absent', 1)

#Check for outliers in data using boxplot
for i,col in enumerate(data):
    fig, ax = plt.subplots()
    fig.set_size_inches(10, 5)
    plt.figure(i)
    plt.title(col)
    sns.boxplot(data=data[col], orient="h")

# %% [markdown]
# ## Missing Values Analysis

# %%
missing_values = pd.DataFrame(data.isnull().sum())
missing_values = missing_values.reset_index()
missing_values = missing_values.rename(columns = {'index': 'Variable', 0: 'Missing'})
missing_values
# Out:
#                            Variable  Missing
# 0                Reason for absence        0
# 1                  Month of absence        0
# 2                   Day of the week        0
# 3                           Seasons        0
# 4            Transportation expense        0
# 5   Distance from Residence to Work        0
# 6                      Service time        0
# 7                               Age        0
# 8            Work load Average/day         0
# 9                        Hit target        0
# 10             Disciplinary failure        0
# 11                        Education        0
# 12                              Son        0
# 13                   Social drinker        0
# 14                    Social smoker        0
# 15                              Pet        0
# 16                           Weight        0
# 17                           Height        0
# 18                  Body mass index        0
